# %% [markdown]
# #### h3avren
# #### kamlesh

# %% [markdown]
# # <center>Bar Plot</center>
#
# A bar plot is drawn in a similar way to a line plot.
# Firstly we will import all the libraries i.e. ```matplolib``` and ```numpy```.

# %% [markdown]
# ### Vertical Bar Plots:
#
# To draw the vertical bar charts we use the bar() method of the pyplot module of the matplotlib library.

# %%
# imports
from matplotlib import pyplot as plt
import numpy as np

# %%
# data to be plotted
years = np.array([2010,2011,2012,2013,2014,2015,2016,2017,2018,2019])
mid_range_cars_sold = np.array([200000,500000,300000,450000,550000,600000,500000,450000,650000,600000]) 
two_wheelers_sold = np.array([500000,600000,700000,750000,400000,400000,350000,300000,400000,500000])
elite_range_cars_sold = np.array([510000,610000,720000,730000,430000,450000,650000,400000,300000,200000])

# offset
offset=0.25

#m

# %%
# plotting the data for mid range cars
plt.bar(years-offset,mid_range_cars_sold,width=offset,color="#bdac3d",label="Mid range cars")

# plotting the data for elite range of cars
plt.bar(years,elite_range_cars_sold,width=offset,color="#eedafa",label="Elite range cars")

# plotting data for two wheelers
plt.bar(years+offset,two_wheelers_sold,width=offset,color="#33fdbd",label="Two Wheelers Sold")

plt.legend()
plt.title("Vehicle Sales")
plt.xlabel("Years")
plt.ylabel("Sales")
plt.xticks(ticks=years,label=years) # not all ticks are shown by default and also sometimes 
# we require to change the ticks to have different values that's where the xticks() method comes in handy
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Horizontal Bar Plots:
#
# To draw horizontal bar plots we simply replace the ```bar()``` method with the ```barh()``` method.

# %%
# plotting the data for mid range cars
plt.barh(years-offset,mid_range_cars_sold)#,width=offset,color="#bdac3d",label="Mid range cars")

# plotting the data for elite range of cars
plt.barh(years,elite_range_cars_sold)#,width=offset,color="#eedafa",label="Elite range cars")

# plotting data for two wheelers
plt.barh(years+offset,two_wheelers_sold)#,width=offset,color="#33fdbd",label="Two Wheelers Sold")

plt.legend()
plt.title("Vehicle Sales")
# plt.xlabel("Years")
# plt.ylabel("Sales")
plt.xticks(ticks=years,label=years) # not all ticks are shown by default and also sometimes 
# we require to change the ticks to have different values that's where the xticks() method comes in handy
plt.tight_layout()
plt.show()# plotting the data for mid range cars
plt.bar(years-offset,mid_range_cars_sold,width=offset,color="#bdac3d",label="Mid range cars")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-211d0c0a6ca7> in <module>
#       1 # plotting the data for mid range cars
# ----> 2 plt.barh(years-offset,mid_range_cars_sold,width=offset)#,color="#bdac3d",label="Mid range cars")
#       3
#       4 # plotting the data for elite range of cars
#       5 plt.barh(years,elite_range_cars_sold)#,width=offset,color="#eedafa",label="Elite range cars")
#
# TypeError: barh() got multiple values for argument 'width'
